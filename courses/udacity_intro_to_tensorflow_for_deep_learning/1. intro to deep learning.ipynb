# %% [markdown]
# In Traditional software developer we know the inputs, outputs and the algorithms as well

# %% [markdown]
# In Machine learning we know inputs and output only the algorithum is not known
# and machine have to guess or assume a kind of algorithm by itself or we can say machine will figure out.

# %% [markdown]
# The machine learning approch uses a neural network to learn the relationships of input and outputs

# %% [markdown]
# We can think of a nural network as a stack of layers where each layer consist of math and some internal variables.

# %% [markdown]
# When we fed an input to a model
#
#
# *   the input goes throgh each layer and math and internal variables are applied to yet and hene an output is produced

# %% [markdown]
# In order for a neural network to work we need to train it.
# we train a neural network by letting it repeatedly map the input to the output.
# And while training tuning the internal variables in the layers until the network learns to produce a good output.

# %% [markdown]
# We can think of machine learning algorithm as a function that can tune variable in order to correctly maps some input to output.

# %% [markdown]
# Training a simple model
# https://colab.research.google.com/github/tensorflow/examples/blob/master/courses/udacity_intro_to_tensorflow_for_deep_learning/l02c01_celsius_to_fahrenheit.ipynb
